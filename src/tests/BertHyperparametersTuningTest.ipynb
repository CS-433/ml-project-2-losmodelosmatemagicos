# %%
import pickle
import numpy as np
import sys
sys.path.append('../ml/BERT')
from Config import Config
from Vectorisation import Vectorisation
import masking
import BERT

import tensorflow as tf
from sklearn.model_selection import KFold
from itertools import product
# Out:
# WARNING:tensorflow:From c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
hyperparameters = {
    #"EMBED_DIM": [32, 64, 128, 256],
    #"NUM_HEAD": [2, 4, 8],
    #"FF_DIM": [32, 64, 128, 256],
    #"NUM_LAYERS": [1, 2, 4],
    "LR": [0.0001, 0.001, 0.01],
    #"EPOCH": [10, 20, 30]
}
num_folds = 10

# %%
with open("../../data/ml4science_data.pkl", "rb") as fp:
    full_data = pickle.load(fp)

data_list = [full_data["sequences"][i]["sequence"] for i in range(len(full_data["sequences"]))]

# %%
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
for hyperparameter in hyperparameters.items():
    print(f"Testing {hyperparameter[0]}")
    accuracy_list = []

    for value in hyperparameter[1]:
        print(f"\n\nTesting {hyperparameter[0]} with value {value}")
        match hyperparameter[0]:
            case "EMBED_DIM":
                config = Config(EMBED_DIM=value)
            case "NUM_HEAD":
                config = Config(NUM_HEAD=value)
            case "FF_DIM":
                config = Config(FF_DIM=value)
            case "NUM_LAYERS":
                config = Config(NUM_LAYERS=value)
            case "LR":
                config = Config(LR=value)
            case "EPOCH":
                config = Config(EPOCH=value)

        vectorisation = Vectorisation(config)
        accuracies = []

        for i, (train_index, test_index) in enumerate(kf.split(data_list)):
            print("\n\n=========================================")
            print(f"In fold {i + 1}\n")

            train_data = [data_list[i] for i in train_index]
            test_data = [data_list[i] for i in test_index]

            train_data_encoded = vectorisation.encode(train_data)
            test_data_encoded = vectorisation.encode(test_data)

            x_masked_train, y_masked_train, sample_weights_train = masking.mask_input_and_labels(train_data_encoded, config.TOKEN_DICT, seed=32)
            x_masked_test, y_masked_test, sample_weights_test = masking.mask_input_and_labels(test_data_encoded, config.TOKEN_DICT, seed=32)

            mlm_ds_train = tf.data.Dataset.from_tensor_slices((x_masked_train, y_masked_train, sample_weights_train))
            mlm_ds_train = mlm_ds_train.shuffle(1000).batch(config.BATCH_SIZE)
            mlm_ds_test = tf.data.Dataset.from_tensor_slices((x_masked_test, y_masked_test, sample_weights_test))
            mlm_ds_test = mlm_ds_test.shuffle(1000).batch(config.BATCH_SIZE)

            bert_masked_model = BERT.create_masked_language_bert_model(config)
            bert_masked_model.fit(mlm_ds_train, epochs=20, validation_data=mlm_ds_test)

            predictions = bert_masked_model.predict(x_masked_test)
            predictions_max = np.argmax(predictions, axis=2)

            accuracy = np.sum((predictions_max == y_masked_test) * (x_masked_test == config.TOKEN_DICT['[MASK]'])) / np.sum(x_masked_test == config.TOKEN_DICT['[MASK]'])
            accuracies.append(accuracy)

        accuracy_list.append(np.mean(accuracies))

    print(f"The best value for {hyperparameter[0]} is {hyperparameter[1][np.argmax(accuracy_list)]} with an accuracy of {np.max(accuracy_list)}")
# Out:
# Testing LR
#
#
# Testing LR with value 0.0001
#
#
# =========================================
# In fold 1
#
# WARNING:tensorflow:From c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.9848WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 27ms/step - loss: 3.9581 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.6973WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.6822 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.4633WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.4531 - val_loss: 0.0000e+00
# Epoch 4/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.2738WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 3.2797 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1367WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 3.1495 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0344WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 3.0380 - val_loss: 0.0000e+00
# Epoch 7/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9755WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.9709 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9081WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.9083 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8617WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.8690 - val_loss: 0.0000e+00
# Epoch 10/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8376WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.8320 - val_loss: 0.0000e+00
# Epoch 11/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7930WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7968 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7755WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.7779 - val_loss: 0.0000e+00
# Epoch 13/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7450WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.7444 - val_loss: 0.0000e+00
# Epoch 14/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7289WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.7370 - val_loss: 0.0000e+00
# Epoch 15/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7024WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7142 - val_loss: 0.0000e+00
# Epoch 16/20
# 15/15 [==============================] - ETA: 0s - loss: 2.7061WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7061 - val_loss: 0.0000e+00
# Epoch 17/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6710WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.6815 - val_loss: 0.0000e+00
# Epoch 18/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6824WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6818 - val_loss: 0.0000e+00
# Epoch 19/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6643WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.6663 - val_loss: 0.0000e+00
# Epoch 20/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6435WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.6442 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 172ms/step
#
#
# =========================================
# In fold 2
#
# Epoch 1/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.9394WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 23ms/step - loss: 3.9386 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.6722WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.6631 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.4653WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.4528 - val_loss: 0.0000e+00
# Epoch 4/20
# 15/15 [==============================] - ETA: 0s - loss: 3.2876WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 3.2876 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1454WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.1653 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0903WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.0782 - val_loss: 0.0000e+00
# Epoch 7/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0067WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.9926 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9596WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.9484 - val_loss: 0.0000e+00
# Epoch 9/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.9198WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8978 - val_loss: 0.0000e+00
# Epoch 10/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8450WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8613 - val_loss: 0.0000e+00
# Epoch 11/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8281 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8112WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8042 - val_loss: 0.0000e+00
# Epoch 13/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7815WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7888 - val_loss: 0.0000e+00
# Epoch 14/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7506WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7665 - val_loss: 0.0000e+00
# Epoch 15/20
# 15/15 [==============================] - ETA: 0s - loss: 2.7478WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7478 - val_loss: 0.0000e+00
# Epoch 16/20
# 15/15 [==============================] - ETA: 0s - loss: 2.7417WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7417 - val_loss: 0.0000e+00
# Epoch 17/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.6984WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7182 - val_loss: 0.0000e+00
# Epoch 18/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7072WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7041 - val_loss: 0.0000e+00
# Epoch 19/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6997WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6969 - val_loss: 0.0000e+00
# Epoch 20/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6866WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.6825 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 130ms/step
#
#
# =========================================
# In fold 3
#
# Epoch 1/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.6503WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 23ms/step - loss: 3.6320 - val_loss: 0.0000e+00
# Epoch 2/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.4509WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 3.4227 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.2770WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.2695 - val_loss: 0.0000e+00
# Epoch 4/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1495WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.1508 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0583WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.0585 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0113WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 2.9885 - val_loss: 0.0000e+00
# Epoch 7/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9360WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.9276 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8867WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8891 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8367WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.8487 - val_loss: 0.0000e+00
# Epoch 10/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.8368WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.8267 - val_loss: 0.0000e+00
# Epoch 11/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8102WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7945 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7775WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.7756 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7606WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.7554 - val_loss: 0.0000e+00
# Epoch 14/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7472WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.7314 - val_loss: 0.0000e+00
# Epoch 15/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7328WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7176 - val_loss: 0.0000e+00
# Epoch 16/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6939WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.7009 - val_loss: 0.0000e+00
# Epoch 17/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6797WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6817 - val_loss: 0.0000e+00
# Epoch 18/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.6573WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6827 - val_loss: 0.0000e+00
# Epoch 19/20
# 15/15 [==============================] - ETA: 0s - loss: 2.6705WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.6705 - val_loss: 0.0000e+00
# Epoch 20/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.6707WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6491 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 138ms/step
#
#
# =========================================
# In fold 4
#
# Epoch 1/20
# 11/15 [=====================>........] - ETA: 0s - loss: 4.0081WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 25ms/step - loss: 3.9640 - val_loss: 0.0000e+00
# Epoch 2/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.7357WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 3.6950 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.5036WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4870 - val_loss: 0.0000e+00
# Epoch 4/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.3329WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.3230 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.2142WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.2036 - val_loss: 0.0000e+00
# Epoch 6/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.1107WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 3.1065 - val_loss: 0.0000e+00
# Epoch 7/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.0317WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 3.0296 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9687WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.9748 - val_loss: 0.0000e+00
# Epoch 9/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.9190WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.9231 - val_loss: 0.0000e+00
# Epoch 10/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8878WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 22ms/step - loss: 2.8815 - val_loss: 0.0000e+00
# Epoch 11/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8748WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.8585 - val_loss: 0.0000e+00
# Epoch 12/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.8328WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.8249 - val_loss: 0.0000e+00
# Epoch 13/20
#  5/15 [=========>....................] - ETA: 0s - loss: 2.7695
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 43
#      40 mlm_ds_test = mlm_ds_test.shuffle(1000).batch(config.BATCH_SIZE)
#      42 bert_masked_model = BERT.create_masked_language_bert_model(config)
# ---> 43 bert_masked_model.fit(mlm_ds_train, epochs=20, validation_data=mlm_ds_test)
#      45 predictions = bert_masked_model.predict(x_masked_test)
#      46 predictions_max = np.argmax(predictions, axis=2)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
