# %%
import pickle
import numpy as np
import sys
sys.path.append('../ml/BERT')
from Config import Config
from Vectorisation import Vectorisation
import masking
import BERT

import tensorflow as tf
from sklearn.model_selection import KFold
from itertools import product
# Out:
# WARNING:tensorflow:From c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
hyperparameters = {
    #"EMBED_DIM": [32, 64, 128, 256],
    #"NUM_HEAD": [2, 4, 8],
    #"FF_DIM": [32, 64, 128, 256],
    "NUM_LAYERS": [1, 2, 4],
    "LR": [0.0001, 0.001, 0.01],
    #"EPOCH": [10, 20, 30]
}
num_folds = 10

# %%
with open("../../data/ml4science_data.pkl", "rb") as fp:
    full_data = pickle.load(fp)

data_list = [full_data["sequences"][i]["sequence"] for i in range(len(full_data["sequences"]))]

# %%
accuracy_list = []
hyperparameters_combinations = []
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

for hyperparameter in product(*hyperparameters.values()):
    config = Config(NUM_LAYERS=hyperparameter[0], LR=hyperparameter[1])
    vectorisation = Vectorisation(config)

    hyperparameters_combinations.append(hyperparameter)
    accuracies = []

    for train_index, test_index in kf.split(data_list):
        train_data = [data_list[i] for i in train_index]
        test_data = [data_list[i] for i in test_index]

        train_data_encoded = vectorisation.encode(train_data)
        test_data_encoded = vectorisation.encode(test_data)

        x_masked_train, y_masked_train, sample_weights_train = masking.mask_input_and_labels(train_data_encoded, config.TOKEN_DICT, seed=32)
        x_masked_test, y_masked_test, sample_weights_test = masking.mask_input_and_labels(test_data_encoded, config.TOKEN_DICT, seed=32)

        mlm_ds_train = tf.data.Dataset.from_tensor_slices((x_masked_train, y_masked_train, sample_weights_train))
        mlm_ds_train = mlm_ds_train.shuffle(1000).batch(config.BATCH_SIZE)
        mlm_ds_test = tf.data.Dataset.from_tensor_slices((x_masked_test, y_masked_test, sample_weights_test))
        mlm_ds_test = mlm_ds_test.shuffle(1000).batch(config.BATCH_SIZE)

        bert_masked_model = BERT.create_masked_language_bert_model(config)

        bert_masked_model.fit(mlm_ds_train, epochs=20, validation_data=mlm_ds_test)

        predictions = bert_masked_model.predict(x_masked_test)
        predictions_max = np.argmax(predictions, axis=2)

        accuracy = np.sum((predictions_max == y_masked_test) * (x_masked_test == config.TOKEN_DICT['[MASK]'])) / np.sum(x_masked_test == config.TOKEN_DICT['[MASK]'])
        accuracies.append(accuracy)

    accuracy_list.append(np.mean(accuracies))

print(f"The best hyperparameters values for {list(hyperparameters.keys())} are {hyperparameters_combinations[np.argmax(accuracy_list)]} with an accuracy of {np.max(accuracy_list)}")
# Out:
# WARNING:tensorflow:From c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.9202WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 27ms/step - loss: 3.9008 - val_loss: 0.0000e+00
# Epoch 2/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.6721WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.6753 - val_loss: 0.0000e+00
# Epoch 3/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.5010WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 13ms/step - loss: 3.5005 - val_loss: 0.0000e+00
# Epoch 4/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.3294WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.3286 - val_loss: 0.0000e+00
# Epoch 5/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.2096WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.2147 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1137WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 3.1080 - val_loss: 0.0000e+00
# Epoch 7/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.0210WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 3.0222 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9658WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.9603 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8939WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.9002 - val_loss: 0.0000e+00
# Epoch 10/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8765WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8579 - val_loss: 0.0000e+00
# Epoch 11/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8287WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8167 - val_loss: 0.0000e+00
# Epoch 12/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7807WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7769 - val_loss: 0.0000e+00
# Epoch 13/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7535WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7591 - val_loss: 0.0000e+00
# Epoch 14/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7369WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7303 - val_loss: 0.0000e+00
# Epoch 15/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.6986WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7131 - val_loss: 0.0000e+00
# Epoch 16/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7078WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7016 - val_loss: 0.0000e+00
# Epoch 17/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6862WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6823 - val_loss: 0.0000e+00
# Epoch 18/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.6773WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.6710 - val_loss: 0.0000e+00
# Epoch 19/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6582WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.6661 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6333WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.6450 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 157ms/step
# Epoch 1/20
# 13/15 [=========================>....] - ETA: 0s - loss: 4.0641WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 3s 55ms/step - loss: 4.0351 - val_loss: 0.0000e+00
# Epoch 2/20
# 15/15 [==============================] - ETA: 0s - loss: 3.7618WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 33ms/step - loss: 3.7618 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.5350WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 33ms/step - loss: 3.5218 - val_loss: 0.0000e+00
# Epoch 4/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.3360WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 34ms/step - loss: 3.3353 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.2042WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 35ms/step - loss: 3.1976 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1064WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 31ms/step - loss: 3.0940 - val_loss: 0.0000e+00
# Epoch 7/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.0171WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 44ms/step - loss: 3.0173 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9438WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 32ms/step - loss: 2.9518 - val_loss: 0.0000e+00
# Epoch 9/20
# 15/15 [==============================] - ETA: 0s - loss: 2.9073WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 31ms/step - loss: 2.9073 - val_loss: 0.0000e+00
# Epoch 10/20
# 15/15 [==============================] - ETA: 0s - loss: 2.8528WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 36ms/step - loss: 2.8528 - val_loss: 0.0000e+00
# Epoch 11/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.8235WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 32ms/step - loss: 2.8255 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8191WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 33ms/step - loss: 2.8028 - val_loss: 0.0000e+00
# Epoch 13/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7700WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 45ms/step - loss: 2.7698 - val_loss: 0.0000e+00
# Epoch 14/20
# 15/15 [==============================] - ETA: 0s - loss: 2.7489WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 31ms/step - loss: 2.7489 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7492WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 38ms/step - loss: 2.7455 - val_loss: 0.0000e+00
# Epoch 16/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7260WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 32ms/step - loss: 2.7174 - val_loss: 0.0000e+00
# Epoch 17/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7019WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 32ms/step - loss: 2.7027 - val_loss: 0.0000e+00
# Epoch 18/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6971WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 37ms/step - loss: 2.6893 - val_loss: 0.0000e+00
# Epoch 19/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6985WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 32ms/step - loss: 2.6860 - val_loss: 0.0000e+00
# Epoch 20/20
# 15/15 [==============================] - ETA: 0s - loss: 2.6653WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 31ms/step - loss: 2.6653 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 405ms/step
# Epoch 1/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.9017WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 6s 57ms/step - loss: 3.9056 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.6698WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 32ms/step - loss: 3.6705 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.4836WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 30ms/step - loss: 3.4862 - val_loss: 0.0000e+00
# Epoch 4/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.3306WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 33ms/step - loss: 3.3388 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.2039WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 34ms/step - loss: 3.2091 - val_loss: 0.0000e+00
# Epoch 6/20
# 15/15 [==============================] - ETA: 0s - loss: 3.1156WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 41ms/step - loss: 3.1156 - val_loss: 0.0000e+00
# Epoch 7/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.0349WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 37ms/step - loss: 3.0389 - val_loss: 0.0000e+00
# Epoch 8/20
# 15/15 [==============================] - ETA: 0s - loss: 2.9731WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.9731 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9293WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.9275 - val_loss: 0.0000e+00
# Epoch 10/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8783WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8831 - val_loss: 0.0000e+00
# Epoch 11/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8432WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8407 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8313WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8131 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7908WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7901 - val_loss: 0.0000e+00
# Epoch 14/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7614WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7725 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7494WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7568 - val_loss: 0.0000e+00
# Epoch 16/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7182WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7374 - val_loss: 0.0000e+00
# Epoch 17/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7240WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 2.7252 - val_loss: 0.0000e+00
# Epoch 18/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7053WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.7031 - val_loss: 0.0000e+00
# Epoch 19/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7019WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7002 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6708WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.6864 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 126ms/step
# Epoch 1/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.8820WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 26ms/step - loss: 3.8646 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.6574WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 3.6591 - val_loss: 0.0000e+00
# Epoch 3/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.5080WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 3.4787 - val_loss: 0.0000e+00
# Epoch 4/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.3436WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 3.3280 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.2302WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.2088 - val_loss: 0.0000e+00
# Epoch 6/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.1125WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 3.1036 - val_loss: 0.0000e+00
# Epoch 7/20
# 15/15 [==============================] - ETA: 0s - loss: 3.0311WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 3.0311 - val_loss: 0.0000e+00
# Epoch 8/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.9438WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.9623 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8889WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 22ms/step - loss: 2.9093 - val_loss: 0.0000e+00
# Epoch 10/20
# 15/15 [==============================] - ETA: 0s - loss: 2.8649WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.8649 - val_loss: 0.0000e+00
# Epoch 11/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8289WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.8434 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7923WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8025 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7934WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 2.7913 - val_loss: 0.0000e+00
# Epoch 14/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7807WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7651 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7385WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7516 - val_loss: 0.0000e+00
# Epoch 16/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7427WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7399 - val_loss: 0.0000e+00
# Epoch 17/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7160WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7156 - val_loss: 0.0000e+00
# Epoch 18/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7088WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7015 - val_loss: 0.0000e+00
# Epoch 19/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.6971WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6911 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6648WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.6723 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 145ms/step
# Epoch 1/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.8352WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 30ms/step - loss: 3.8331 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.6140WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 3.5977 - val_loss: 0.0000e+00
# Epoch 3/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.4134WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 3.4166 - val_loss: 0.0000e+00
# Epoch 4/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.2728WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 3.2710 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1662WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 3.1584 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0845WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 3.0793 - val_loss: 0.0000e+00
# Epoch 7/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.0288WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 3.0106 - val_loss: 0.0000e+00
# Epoch 8/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.9464WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.9470 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9176WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.9009 - val_loss: 0.0000e+00
# Epoch 10/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8845WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.8668 - val_loss: 0.0000e+00
# Epoch 11/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.8016WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8184 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7933WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7877 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7641WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7659 - val_loss: 0.0000e+00
# Epoch 14/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7210WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.7380 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7301WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7199 - val_loss: 0.0000e+00
# Epoch 16/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7141WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7102 - val_loss: 0.0000e+00
# Epoch 17/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6883WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6835 - val_loss: 0.0000e+00
# Epoch 18/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6738WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.6726 - val_loss: 0.0000e+00
# Epoch 19/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6742WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 2.6591 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6564WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.6488 - val_loss: 0.0000e+00
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021DD6FEBE20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 145ms/step
# Epoch 1/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.9725WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 25ms/step - loss: 3.9679 - val_loss: 0.0000e+00
# Epoch 2/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.7307WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 14ms/step - loss: 3.7298 - val_loss: 0.0000e+00
# Epoch 3/20
# 15/15 [==============================] - ETA: 0s - loss: 3.5127WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# ...
# 15/15 [==============================] - 0s 23ms/step - loss: 2.5157 - val_loss: 0.0000e+00
# Epoch 7/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.5018WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.4926 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.4744WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.4649 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.4434WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.4330 - val_loss: 0.0000e+00
# Epoch 10/20
# 15/15 [==============================] - ETA: 0s - loss: 2.3971WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 22ms/step - loss: 2.3971 - val_loss: 0.0000e+00
# Epoch 11/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.3042WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.3104 - val_loss: 0.0000e+00
# Epoch 12/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.2150WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.2139 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.1721WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 15ms/step - loss: 2.1669 - val_loss: 0.0000e+00
# Epoch 14/20
# 15/15 [==============================] - ETA: 0s - loss: 2.1104WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.1104 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.0836WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 16ms/step - loss: 2.0707 - val_loss: 0.0000e+00
# Epoch 16/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.0255WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.0333 - val_loss: 0.0000e+00
# Epoch 17/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9884WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 1.9921 - val_loss: 0.0000e+00
# Epoch 18/20
# 12/15 [=======================>......] - ETA: 0s - loss: 1.9683WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 1.9538 - val_loss: 0.0000e+00
# Epoch 19/20
# 12/15 [=======================>......] - ETA: 0s - loss: 1.9288WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 1.9024 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 1.8375WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 1.8502 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 179ms/step
# Epoch 1/20
# 12/15 [=======================>......] - ETA: 0s - loss: 3.3199WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 25ms/step - loss: 3.2510 - val_loss: 0.0000e+00
# Epoch 2/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.7552WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.7363 - val_loss: 0.0000e+00
# Epoch 3/20
# 15/15 [==============================] - ETA: 0s - loss: 2.6316WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.6316 - val_loss: 0.0000e+00
# Epoch 4/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.5821WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 18ms/step - loss: 2.5810 - val_loss: 0.0000e+00
# Epoch 5/20
# 12/15 [=======================>......] - ETA: 0s - loss: 2.5605WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 17ms/step - loss: 2.5408 - val_loss: 0.0000e+00
# Epoch 6/20
# 15/15 [==============================] - ETA: 0s - loss: 2.5077WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 19ms/step - loss: 2.5077 - val_loss: 0.0000e+00
# Epoch 7/20
#  8/15 [===============>..............] - ETA: 0s - loss: 2.4711
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 29
#      25 mlm_ds_test = mlm_ds_test.shuffle(1000).batch(config.BATCH_SIZE)
#      27 bert_masked_model = BERT.create_masked_language_bert_model(config)
# ---> 29 bert_masked_model.fit(mlm_ds_train, epochs=20, validation_data=mlm_ds_test)
#      31 predictions = bert_masked_model.predict(x_masked_test)
#      32 predictions_max = np.argmax(predictions, axis=2)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Users\yanni\.conda\envs\ML\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
