# %%
import pickle
import numpy as np
import masking
import BERT
import tensorflow as tf

from Config import Config
from Vectorisation import Vectorisation
from sklearn.model_selection import KFold
from itertools import product
# Out:
# WARNING:tensorflow:From d:\Users\Adrien\miniconda3\envs\ml\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
hyperparameters = {
    #"EMBED_DIM": [32, 64, 128, 256],
    #"NUM_HEAD": [2, 4, 8],
    #"FF_DIM": [32, 64, 128, 256],
    "NUM_LAYERS": [1, 2, 4],
    "LR": [0.0001, 0.001, 0.01],
    #"EPOCH": [10, 20, 30]
}
num_folds = 10

# %%
with open("./ml4science_data.pkl", "rb") as fp:
    full_data = pickle.load(fp)

data_list = [full_data["sequences"][i]["sequence"] for i in range(len(full_data["sequences"]))]

# %%
accuracy_list = []
hyperparameters_combinations = []
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

for hyperparameter in product(*hyperparameters.values()):
    config = Config(NUM_LAYERS=hyperparameter[0], LR=hyperparameter[1])
    vectorisation = Vectorisation(config)

    hyperparameters_combinations.append(hyperparameter)
    accuracies = []

    for train_index, test_index in kf.split(data_list):
        train_data = [data_list[i] for i in train_index]
        test_data = [data_list[i] for i in test_index]

        train_data_encoded = vectorisation.encode(train_data)
        test_data_encoded = vectorisation.encode(test_data)

        x_masked_train, y_masked_train, sample_weights_train = masking.mask_input_and_labels(train_data_encoded, config.TOKEN_DICT, seed=32)
        x_masked_test, y_masked_test, sample_weights_test = masking.mask_input_and_labels(test_data_encoded, config.TOKEN_DICT, seed=32)

        mlm_ds_train = tf.data.Dataset.from_tensor_slices((x_masked_train, y_masked_train, sample_weights_train))
        mlm_ds_train = mlm_ds_train.shuffle(1000).batch(config.BATCH_SIZE)
        mlm_ds_test = tf.data.Dataset.from_tensor_slices((x_masked_test, y_masked_test, sample_weights_test))
        mlm_ds_test = mlm_ds_test.shuffle(1000).batch(config.BATCH_SIZE)

        bert_masked_model = BERT.create_masked_language_bert_model(config)

        bert_masked_model.fit(mlm_ds_train, epochs=20, validation_data=mlm_ds_test)

        predictions = bert_masked_model.predict(x_masked_test)
        predictions_max = np.argmax(predictions, axis=2)

        accuracy = np.sum((predictions_max == y_masked_test) * (x_masked_test == config.TOKEN_DICT['[MASK]'])) / np.sum(x_masked_test == config.TOKEN_DICT['[MASK]'])
        accuracies.append(accuracy)

    accuracy_list.append(np.mean(accuracies))

print(f"The best hyperparameters values for {list(hyperparameters.keys())} are {hyperparameters_combinations[np.argmax(accuracy_list)]} with an accuracy of {np.max(accuracy_list)}")
# Out:
# Epoch 1/20
# 11/15 [=====================>........] - ETA: 0s - loss: 4.0186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 20ms/step - loss: 3.9912 - val_loss: 0.0000e+00
# Epoch 2/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.7570WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.7391 - val_loss: 0.0000e+00
# Epoch 3/20
# 10/15 [===================>..........] - ETA: 0s - loss: 3.5795WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.5540 - val_loss: 0.0000e+00
# Epoch 4/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.4145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.3887 - val_loss: 0.0000e+00
# Epoch 5/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.2637WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.2632 - val_loss: 0.0000e+00
# Epoch 6/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.1717WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.1648 - val_loss: 0.0000e+00
# Epoch 7/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.0825WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.0871 - val_loss: 0.0000e+00
# Epoch 8/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.0243WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 3.0155 - val_loss: 0.0000e+00
# Epoch 9/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.9841WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.9683 - val_loss: 0.0000e+00
# Epoch 10/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.8969WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.9066 - val_loss: 0.0000e+00
# Epoch 11/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.8747WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.8712 - val_loss: 0.0000e+00
# Epoch 12/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.8530WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.8425 - val_loss: 0.0000e+00
# Epoch 13/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.8314WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.8244 - val_loss: 0.0000e+00
# Epoch 14/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7947WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.7768 - val_loss: 0.0000e+00
# Epoch 15/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7677WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.7656 - val_loss: 0.0000e+00
# Epoch 16/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7247WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.7420 - val_loss: 0.0000e+00
# Epoch 17/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7156WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.7244 - val_loss: 0.0000e+00
# Epoch 18/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7484WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.7180 - val_loss: 0.0000e+00
# Epoch 19/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.6877WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.6950 - val_loss: 0.0000e+00
# Epoch 20/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7039WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.6929 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 156ms/step
# test accuracy:  0.1762114537444934
# Epoch 1/20
# 11/15 [=====================>........] - ETA: 0s - loss: 3.3535WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 20ms/step - loss: 3.2483 - val_loss: 0.0000e+00
# Epoch 2/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.7416WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.7354 - val_loss: 0.0000e+00
# Epoch 3/20
# 15/15 [==============================] - ETA: 0s - loss: 2.6311WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.6311 - val_loss: 0.0000e+00
# Epoch 4/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.5751WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.5815 - val_loss: 0.0000e+00
# Epoch 5/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.5799WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.5444 - val_loss: 0.0000e+00
# Epoch 6/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.4902WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.5005 - val_loss: 0.0000e+00
# Epoch 7/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.4651WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.4640 - val_loss: 0.0000e+00
# Epoch 8/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.4261WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.4214 - val_loss: 0.0000e+00
# Epoch 9/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.3700WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.3778 - val_loss: 0.0000e+00
# Epoch 10/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.2671WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.2647 - val_loss: 0.0000e+00
# Epoch 11/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.1377WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.1524 - val_loss: 0.0000e+00
# Epoch 12/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0647WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.0771 - val_loss: 0.0000e+00
# Epoch 13/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0336WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.0411 - val_loss: 0.0000e+00
# Epoch 14/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0326WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.0004 - val_loss: 0.0000e+00
# Epoch 15/20
# 11/15 [=====================>........] - ETA: 0s - loss: 1.9828WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 1.9813 - val_loss: 0.0000e+00
# Epoch 16/20
# 11/15 [=====================>........] - ETA: 0s - loss: 1.9369WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 1.9338 - val_loss: 0.0000e+00
# Epoch 17/20
# 11/15 [=====================>........] - ETA: 0s - loss: 1.9025WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 1.9163 - val_loss: 0.0000e+00
# Epoch 18/20
# 11/15 [=====================>........] - ETA: 0s - loss: 1.8675WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 1.8875 - val_loss: 0.0000e+00
# Epoch 19/20
# 11/15 [=====================>........] - ETA: 0s - loss: 1.8342WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 1.8286 - val_loss: 0.0000e+00
# Epoch 20/20
# 10/15 [===================>..........] - ETA: 0s - loss: 1.8001WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 1.7965 - val_loss: 0.0000e+00
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000016F06618FE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 154ms/step
# test accuracy:  0.28193832599118945
# Epoch 1/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.9437WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 2s 20ms/step - loss: 2.9381 - val_loss: 0.0000e+00
# Epoch 2/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.6128WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.5909 - val_loss: 0.0000e+00
# Epoch 3/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.4959WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.5247 - val_loss: 0.0000e+00
# Epoch 4/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.4627WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.4685 - val_loss: 0.0000e+00
# Epoch 5/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.3792WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.3974 - val_loss: 0.0000e+00
# Epoch 6/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.3501WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.3389 - val_loss: 0.0000e+00
# Epoch 7/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.3129WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.2972 - val_loss: 0.0000e+00
# Epoch 8/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.2774WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.2762 - val_loss: 0.0000e+00
# Epoch 9/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.2440WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.2685 - val_loss: 0.0000e+00
# Epoch 10/20
# 15/15 [==============================] - ETA: 0s - loss: 2.2326WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 13ms/step - loss: 2.2326 - val_loss: 0.0000e+00
# Epoch 11/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.2000WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.1801 - val_loss: 0.0000e+00
# Epoch 12/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.1640WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.1752 - val_loss: 0.0000e+00
# Epoch 13/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.1533WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.1664 - val_loss: 0.0000e+00
# Epoch 14/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.1253WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 13ms/step - loss: 2.1278 - val_loss: 0.0000e+00
# Epoch 15/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.1185WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.1430 - val_loss: 0.0000e+00
# Epoch 16/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0677WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.0827 - val_loss: 0.0000e+00
# Epoch 17/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0814WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.0879 - val_loss: 0.0000e+00
# Epoch 18/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0519WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.0661 - val_loss: 0.0000e+00
# Epoch 19/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0511WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 11ms/step - loss: 2.0458 - val_loss: 0.0000e+00
# Epoch 20/20
# 11/15 [=====================>........] - ETA: 0s - loss: 2.0078WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 12ms/step - loss: 2.0177 - val_loss: 0.0000e+00
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000016F0679F560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 152ms/step
# test accuracy:  0.18502202643171806
# Epoch 1/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.9885WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 3s 34ms/step - loss: 3.9738 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.4702WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 3.4466 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1290WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 3.1217 - val_loss: 0.0000e+00
# Epoch 4/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.9788WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.9645 - val_loss: 0.0000e+00
# Epoch 5/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8699WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.8735 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.8359WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.8301 - val_loss: 0.0000e+00
# Epoch 7/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7781WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.7801 - val_loss: 0.0000e+00
# Epoch 8/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7413WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.7466 - val_loss: 0.0000e+00
# Epoch 9/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7413WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.7298 - val_loss: 0.0000e+00
# Epoch 10/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.7062WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6982 - val_loss: 0.0000e+00
# Epoch 11/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6938WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6980 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6874WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.6785 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6606WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6688 - val_loss: 0.0000e+00
# Epoch 14/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6723WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.6537 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6677WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6493 - val_loss: 0.0000e+00
# Epoch 16/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6288WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6234 - val_loss: 0.0000e+00
# Epoch 17/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6191WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6242 - val_loss: 0.0000e+00
# Epoch 18/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6003WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.6132 - val_loss: 0.0000e+00
# Epoch 19/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6004WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 20ms/step - loss: 2.5996 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6081WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 21ms/step - loss: 2.5955 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 253ms/step
# test accuracy:  0.15418502202643172
# Epoch 1/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1746WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 4s 38ms/step - loss: 3.1280 - val_loss: 0.0000e+00
# Epoch 2/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.6810WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.6752 - val_loss: 0.0000e+00
# Epoch 3/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.5899WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.5890 - val_loss: 0.0000e+00
# Epoch 4/20
# 15/15 [==============================] - ETA: 0s - loss: 2.5471WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.5471 - val_loss: 0.0000e+00
# Epoch 5/20
# 15/15 [==============================] - ETA: 0s - loss: 2.5234WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 25ms/step - loss: 2.5234 - val_loss: 0.0000e+00
# Epoch 6/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.5151WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.5026 - val_loss: 0.0000e+00
# Epoch 7/20
# 15/15 [==============================] - ETA: 0s - loss: 2.4786WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.4786 - val_loss: 0.0000e+00
# Epoch 8/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.4574WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.4583 - val_loss: 0.0000e+00
# Epoch 9/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.3802WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.3807 - val_loss: 0.0000e+00
# Epoch 10/20
# 15/15 [==============================] - ETA: 0s - loss: 2.2832WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.2832 - val_loss: 0.0000e+00
# Epoch 11/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.1781WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.1806 - val_loss: 0.0000e+00
# Epoch 12/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.1394WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.1557 - val_loss: 0.0000e+00
# Epoch 13/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.0990WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.0981 - val_loss: 0.0000e+00
# Epoch 14/20
# 15/15 [==============================] - ETA: 0s - loss: 2.0769WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.0769 - val_loss: 0.0000e+00
# Epoch 15/20
# 13/15 [=========================>....] - ETA: 0s - loss: 2.0435WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.0461 - val_loss: 0.0000e+00
# Epoch 16/20
# 15/15 [==============================] - ETA: 0s - loss: 2.0186WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 2.0186 - val_loss: 0.0000e+00
# Epoch 17/20
# 13/15 [=========================>....] - ETA: 0s - loss: 1.9815WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 1.9807 - val_loss: 0.0000e+00
# Epoch 18/20
# 13/15 [=========================>....] - ETA: 0s - loss: 1.9415WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 1.9312 - val_loss: 0.0000e+00
# Epoch 19/20
# 13/15 [=========================>....] - ETA: 0s - loss: 1.8928WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 1.8855 - val_loss: 0.0000e+00
# Epoch 20/20
# 13/15 [=========================>....] - ETA: 0s - loss: 1.8469WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 0s 24ms/step - loss: 1.8466 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 261ms/step
# test accuracy:  0.2643171806167401
# Epoch 1/20
# 13/15 [=========================>....] - ETA: 0s - loss: 3.1218WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 3s 36ms/step - loss: 3.1053 - val_loss: 0.0000e+00
# Epoch 2/20
# ...
# 15/15 [==============================] - 1s 70ms/step - loss: 2.4478 - val_loss: 0.0000e+00
# Epoch 7/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.4439WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 2.4426 - val_loss: 0.0000e+00
# Epoch 8/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.3314WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 2.3300 - val_loss: 0.0000e+00
# Epoch 9/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.2377WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 2.2394 - val_loss: 0.0000e+00
# Epoch 10/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.1368WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 2.1396 - val_loss: 0.0000e+00
# Epoch 11/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.1024WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 2.1050 - val_loss: 0.0000e+00
# Epoch 12/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.0687WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 2.0690 - val_loss: 0.0000e+00
# Epoch 13/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.0318WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 2.0304 - val_loss: 0.0000e+00
# Epoch 14/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9839WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 1.9867 - val_loss: 0.0000e+00
# Epoch 15/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9686WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 1.9656 - val_loss: 0.0000e+00
# Epoch 16/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9271WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 1.9262 - val_loss: 0.0000e+00
# Epoch 17/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.8720WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 1.8744 - val_loss: 0.0000e+00
# Epoch 18/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.7871WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 69ms/step - loss: 1.7987 - val_loss: 0.0000e+00
# Epoch 19/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.7794WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 1.7729 - val_loss: 0.0000e+00
# Epoch 20/20
# 14/15 [===========================>..] - ETA: 0s - loss: 1.7311WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 70ms/step - loss: 1.7394 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 489ms/step
# test accuracy:  0.3674418604651163
# Epoch 1/20
# 14/15 [===========================>..] - ETA: 0s - loss: 3.0066WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 7s 89ms/step - loss: 3.0044 - val_loss: 0.0000e+00
# Epoch 2/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7328WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.7337 - val_loss: 0.0000e+00
# Epoch 3/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7825WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.7848 - val_loss: 0.0000e+00
# Epoch 4/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7865WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.7902 - val_loss: 0.0000e+00
# Epoch 5/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7481WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 62ms/step - loss: 2.7422 - val_loss: 0.0000e+00
# Epoch 6/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7004WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 62ms/step - loss: 2.7007 - val_loss: 0.0000e+00
# Epoch 7/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7328WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.7292 - val_loss: 0.0000e+00
# Epoch 8/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7145WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.7129 - val_loss: 0.0000e+00
# Epoch 9/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6908WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.6959 - val_loss: 0.0000e+00
# Epoch 10/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6883WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.6954 - val_loss: 0.0000e+00
# Epoch 11/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6895WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.6832 - val_loss: 0.0000e+00
# Epoch 12/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6823WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.6835 - val_loss: 0.0000e+00
# Epoch 13/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6817WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 61ms/step - loss: 2.6838 - val_loss: 0.0000e+00
# Epoch 14/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6913WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.6877 - val_loss: 0.0000e+00
# Epoch 15/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6787WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.6795 - val_loss: 0.0000e+00
# Epoch 16/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6820WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.6830 - val_loss: 0.0000e+00
# Epoch 17/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.7061WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.7074 - val_loss: 0.0000e+00
# Epoch 18/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6669WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.6655 - val_loss: 0.0000e+00
# Epoch 19/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6896WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 60ms/step - loss: 2.6881 - val_loss: 0.0000e+00
# Epoch 20/20
# 14/15 [===========================>..] - ETA: 0s - loss: 2.6856WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# 15/15 [==============================] - 1s 59ms/step - loss: 2.6875 - val_loss: 0.0000e+00
# 1/1 [==============================] - 0s 490ms/step
# test accuracy:  0.13953488372093023
